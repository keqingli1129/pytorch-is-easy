# %%
from transformers import AutoTokenizer
sen ="弱小的我也有大梦想!"

# %%
tokenizer = AutoTokenizer.from_pretrained("uer/roberta-base-finetuned-dianping-chinese")
tokenizer.save_pretrained("./reberta_tokenizer")
# Out:
# ('./reberta_tokenizer/tokenizer_config.json',
#  './reberta_tokenizer/special_tokens_map.json',
#  './reberta_tokenizer/vocab.txt',
#  './reberta_tokenizer/added_tokens.json',
#  './reberta_tokenizer/tokenizer.json')

# %%
tokenizer=AutoTokenizer.from_pretrained("./reberta_tokenizer")

# %%
tokens = tokenizer.tokenize(sen)
tokens
# Out:
# ['弱', '小', '的', '我', '也', '有', '大', '梦', '想', '!']

# %%
tokens = tokenizer.tokenize("how many r's in strawberry?")
tokens
# Out:
# ['how', 'man', '##y', 'r', "'", 's', 'in', 'st', '##ra', '##w', '##berry', '?']

# %%
sen ="弱小的我也有大梦想!有"

# %%
tokenizer.vocab_size
# Out:
# 21128

# %% [markdown]
# # Introduction to Distributed Training with PyTorch and Ray Train
#
# This notebook will show you how to distribute your PyTorch training code with Ray Train and Ray Data, getting performance and usability improvements along the way.
#
# In this tutorial, you:
# 1. Start with a basic single machine PyTorch example.
# 2. Distribute it to multiple GPUs on multiple machines with [Ray Train](https://docs.ray.io/en/latest/train/train.html) and, if you are using an Anyscale Workspace, inspect results with the Ray Train dashboard.
# 3. Scale data ingest separately from training with [Ray Data](https://docs.ray.io/en/latest/data/data.html) and, if you are using an Anyscale Workspace, inspect results with the Ray Data dashboard.

# %% [markdown]
# ## `Step 1`: Start with a basic single machine PyTorch example
#
# In this step you train a PyTorch VisionTransformer model to recognize objects using the open CIFAR-10 dataset. It's a minimal example that trains on a single machine. Note that the code has multiple functions to highlight the changes needed to run things with Ray.

# %% [markdown]
# |<img src="https://anyscale-public-materials.s3.us-west-2.amazonaws.com/ray-ai-libraries/diagrams/single_gpu_pytorch_v3.png" width="70%" loading="lazy">|
# |:--|
# |An overview of the single GPU training process. At a high level, here is how training loop in PyTorch looks like. The key stages include loading the dataset; run the training on mini-batches on a single GPU; saving the model checkpoint to the persistent storage.|

# %%
import os
from typing import Dict

import torch
from filelock import FileLock
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import Normalize, ToTensor
from torchvision.models import VisionTransformer
from tqdm import tqdm

# %% [markdown]
# Next, define a function that returns PyTorch DataLoaders for train and test data. Note how the code also preprocesses the data.

# %%
def get_dataloaders(batch_size):
    # Transform to normalize the input images.
    transform = transforms.Compose([ToTensor(), Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

    # Download training data from open datasets.
    training_data = datasets.CIFAR10(
        root="~/data",
        train=True,
        download=True,
        transform=transform,
    )

    # Download test data from open datasets.
    testing_data = datasets.CIFAR10(
        root="~/data",
        train=False,
        download=True,
        transform=transform,
    )

    # Create data loaders.
    train_dataloader = DataLoader(training_data, batch_size=batch_size, shuffle=True)
    test_dataloader = DataLoader(testing_data, batch_size=batch_size)

    return train_dataloader, test_dataloader

# %% [markdown]
# Now, define a function that runs the core training loop. Note how the code synchronously alternates between training the model for one epoch and then evaluating its performance.

# %%
def train_func():
    lr = 1e-3
    epochs = 1
    batch_size = 512

    # Get data loaders inside the worker training function.
    train_dataloader, valid_dataloader = get_dataloaders(batch_size=batch_size)

    model = VisionTransformer(
        image_size=32,   # CIFAR-10 image size is 32x32
        patch_size=4,    # Patch size is 4x4
        num_layers=12,   # Number of transformer layers
        num_heads=8,     # Number of attention heads
        hidden_dim=384,  # Hidden size (can be adjusted)
        mlp_dim=768,     # MLP dimension (can be adjusted)
        num_classes=10   # CIFAR-10 has 10 classes
    )
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)

    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-2)

    # Model training loop.
    for epoch in range(epochs):
        model.train()
        for X, y in tqdm(train_dataloader, desc=f"Train Epoch {epoch}"):
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss = loss_fn(pred, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        valid_loss, num_correct, num_total = 0, 0, 0
        with torch.no_grad():
            for X, y in tqdm(valid_dataloader, desc=f"Valid Epoch {epoch}"):
                X, y = X.to(device), y.to(device)
                pred = model(X)
                loss = loss_fn(pred, y)

                valid_loss += loss.item()
                num_total += y.shape[0]
                num_correct += (pred.argmax(1) == y).sum().item()

        valid_loss /= len(train_dataloader)
        accuracy = num_correct / num_total

        print({"epoch_num": epoch, "loss": valid_loss, "accuracy": accuracy})

# %% [markdown]
# Finally, run training.

# %%
# train_func()

# %% [markdown]
# ## `Step 2`: Distribute training to multiple machines with Ray Train

# %% [markdown]
# Next, modify this example to run with Ray Train on multiple machines with distributed data parallel (DDP) training. In DDP training, each process trains a copy of the model on a subset of the data and synchronizes gradients across all processes after each backward pass to keep models consistent. Essentially, Ray Train allows you to wrap PyTorch training code in a function and run the function on each worker in your Ray Cluster. With a few modifications, you get the fault tolerance and auto-scaling of a [Ray Cluster](https://docs.ray.io/en/latest/cluster/getting-started.html), as well as the observability and ease-of-use of [Ray Train](https://docs.ray.io/en/latest/train/train.html).
#
# First, set some environment variables and import some modules.

# %% [markdown]
# ### Architecture overview
#
# Ray Train's architecture is based on the following components:
# 1. A `Ray Train Controller/Driver` that schedules the training workers, handles errors and manages checkpoints
# 2. `Ray Train Worker` executing the training code

# %% [markdown]
# <img src="https://anyscale-materials.s3.us-west-2.amazonaws.com/ray-train-deep-dive/train_architecture.jpg" loading="lazy" width="700">

# %% [markdown]
# ### Key API concepts
#
# Below are the key API concepts of Ray Train:
#
# 1. `train_loop_per_worker`: This is the main function that contains your model training logic.
# 2. `ScalingConfig`: This is used to specify the number of workers and compute resources (CPUs or GPUs, TPUs).
# 3. `Trainer`: This is used to manage the training process.
# 4. `Trainer.fit()`: This is used to start the training process.
#
# <img src="https://docs.ray.io/en/latest/_images/overview.png" width="700" loading="lazy">

# %% [markdown]
# Below is the diagram showing how the key components usually work together.
#
# - The Train Controller/Driver is constantly performing health checks on the Train workers.
# - The Train workers are running the training loop and at a particular frequency checkpointing the model to a persistent storage.
#
# <img src="https://anyscale-materials.s3.us-west-2.amazonaws.com/ray-train-deep-dive/ray_train_detailed_architecture.png" width="800" loading="lazy">

# %% [markdown]
# Let's consider the case where we have a very large dataset of images that would take a long time to train on a single GPU. We would now like to scale this training job to run on multiple GPUs.
#
# |<img src="https://anyscale-public-materials.s3.us-west-2.amazonaws.com/ray-ai-libraries/diagrams/multi_gpu_pytorch_v4.png" width="70%" loading="lazy">|
# |:--|
# |Schematic overview of DistributedDataParallel (DDP) training: (1) the model is replicated from the <code>GPU rank 0</code> to all other workers; (2) each worker receives a shard of the dataset and processes a mini-batch; (3) during the backward pass, gradients are averaged across GPUs; (4) checkpoint and metrics from rank 0 GPU are saved to the persistent storage.|

# %%
import ray.train
from ray.train import RunConfig, ScalingConfig
from ray.train.torch import TorchTrainer

import tempfile
import uuid

# %% [markdown]
# Next, modify the training function you wrote earlier. Every difference from the previous script is highlighted and explained with a numbered comment; for example, “[1].”

# %%
def train_func_per_worker(config: Dict):
    lr = config["lr"]
    epochs = config["epochs"]
    batch_size = config["batch_size_per_worker"]

    # Step 1: Prepare data loader for distributed training.
    #         The prepare_data_loader method assigns unique rows of data to each worker so that
    #         the model sees each row once per epoch.
    # =========================================================================================
    train_dataloader, valid_dataloader = get_dataloaders(batch_size=batch_size)
    train_dataloader = ray.train.torch.prepare_data_loader(train_dataloader)
    valid_dataloader = ray.train.torch.prepare_data_loader(valid_dataloader)

    model = VisionTransformer(
        image_size=32,   # CIFAR-10 image size is 32x32
        patch_size=4,    # Patch size is 4x4
        num_layers=12,   # Number of transformer layers
        num_heads=8,     # Number of attention heads
        hidden_dim=384,  # Hidden size (can be adjusted)
        mlp_dim=768,     # MLP dimension (can be adjusted)
        num_classes=10   # CIFAR-10 has 10 classes
    )

    # Step 2: Prepare and wrap your model with DistributedDataParallel.
    #         The prepare_model method moves the model to the correct GPU/CPU device.
    # ===============================================================================
    model = ray.train.torch.prepare_model(model)

    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-2)

    # Step 3: Model training loop.
    # ============================
    for epoch in range(epochs):
        if ray.train.get_context().get_world_size() > 1:
            # Required for the distributed sampler to shuffle properly across epochs.
            train_dataloader.sampler.set_epoch(epoch)

        model.train()
        for X, y in tqdm(train_dataloader, desc=f"Train Epoch {epoch}"):
            pred = model(X)
            loss = loss_fn(pred, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        valid_loss, num_correct, num_total = 0, 0, 0
        with torch.no_grad():
            for X, y in tqdm(valid_dataloader, desc=f"Valid Epoch {epoch}"):
                pred = model(X)
                loss = loss_fn(pred, y)

                valid_loss += loss.item()
                num_total += y.shape[0]
                num_correct += (pred.argmax(1) == y).sum().item()

        valid_loss /= len(train_dataloader)
        accuracy = num_correct / num_total

        # Step 4: Report checkpoints and attached metrics to Ray Train.
        # =============================================================
        metrics = print_metrics_ray_train(loss, epoch)
        save_checkpoint_and_metrics_ray_train(model, metrics)

# %%
def print_metrics_ray_train(loss: torch.Tensor, epoch: int) -> None:
    metrics = {"loss": loss.item(), "epoch": epoch}
    world_rank = ray.train.get_context().get_world_rank() # report from all workers
    print(f"{metrics=} {world_rank=}")
    
    return metrics

def save_checkpoint_and_metrics_ray_train(
    model: torch.nn.Module, metrics: dict[str, float]
) -> None:
    with tempfile.TemporaryDirectory() as temp_checkpoint_dir:
        torch.save(
            model.module.state_dict(),  # note the `.module` to unwrap the DistributedDataParallel
            os.path.join(temp_checkpoint_dir, "model.pt"),
        )

        ray.train.report(
            metrics,
            checkpoint=ray.train.Checkpoint.from_directory(temp_checkpoint_dir),
        )

# %% [markdown]
# Finally, run the training function on the Ray Cluster with a TorchTrainer using GPU workers.
#
# The `TorchTrainer` takes the following arguments:
# * **`train_loop_per_worker`**: the training function you defined earlier. Each Ray Train worker runs this function. Note that you can call special Ray Train functions from within this function.
# * **`train_loop_config`**: a hyperparameter dictionary. Each Ray Train worker calls its `train_loop_per_worker` function with this dictionary.
# * **`scaling_config`**: a configuration object that specifies the number of workers and compute resources, for example, CPUs or GPUs, that your training run needs.
# * **`run_config`**: a configuration object that specifies various fields used at runtime, including the path to save checkpoints.
#
# **`trainer.fit()`** spawns a controller process to orchestrate the training run and worker processes to actually execute the PyTorch training code.

# %%
num_workers=2
use_gpu=True
global_batch_size = 512
lr = 1e-3
epochs = 2

train_config = {
    "lr": lr,
    "epochs": epochs,
    "batch_size_per_worker": global_batch_size // num_workers,
}

scaling_config = ScalingConfig(num_workers=num_workers, 
                               use_gpu=use_gpu)

run_config = RunConfig(storage_path="/mnt/cluster_storage", 
                       name=f"train_run-{uuid.uuid4().hex}")

trainer = TorchTrainer(
    train_loop_per_worker=train_func_per_worker,
    train_loop_config=train_config,
    scaling_config=scaling_config,
    run_config=run_config,
)

result = trainer.fit()
print(f"Training result: {result}")
# Out:
# 2026-03-16 16:21:49,108	INFO worker.py:1810 -- Connecting to existing Ray cluster at address: 10.0.228.114:6379...
# 2026-03-16 16:21:49,132	INFO worker.py:2004 -- Connected to Ray cluster. View the dashboard at https://session-w9hutqjs6uvhf2vxxemg8rde8q.i.anyscaleuserdata.com
# 2026-03-16 16:21:49,135	INFO packaging.py:463 -- Pushing file package 'gcs://_ray_pkg_7416dc9948c3516e269a6aa579e9f5d9104bd9b8.zip' (0.05MiB) to Ray cluster...
# 2026-03-16 16:21:49,136	INFO packaging.py:476 -- Successfully pushed file package 'gcs://_ray_pkg_7416dc9948c3516e269a6aa579e9f5d9104bd9b8.zip'.
# /home/ray/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py:2052: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# (TrainController pid=14603) [State Transition] INITIALIZING -> SCHEDULING.
# (TrainController pid=14603) Attempting to start training worker group of size 2 with the following resources: [{'GPU': 1}] * 2
# (RayTrainWorker pid=5004, ip=10.0.252.174) Setting up process group for: env:// [rank=0, world_size=2]
# (TrainController pid=14603) Started training worker group of size 2:
# (TrainController pid=14603) - (ip=10.0.252.174, pid=5004) world_rank=0, local_rank=0, node_rank=0
# (TrainController pid=14603) - (ip=10.0.201.237, pid=4974) world_rank=1, local_rank=0, node_rank=1
# (TrainController pid=14603) [State Transition] SCHEDULING -> RUNNING.
#   0%|          | 0.00/170M [00:00<?, ?B/s].174)
#   0%|          | 65.5k/170M [00:00<04:38, 613kB/s]m
#   0%|          | 164k/170M [00:00<03:34, 794kB/s] m
#  92%|█████████▏| 158M/170M [00:03<00:00, 44.9MB/s]m
#  95%|█████████▌| 162M/170M [00:04<00:00, 44.1MB/s]m
#  92%|█████████▏| 157M/170M [00:03<00:00, 42.9MB/s]m
#  98%|█████████▊| 167M/170M [00:04<00:00, 43.2MB/s]m
#  95%|█████████▌| 163M/170M [00:04<00:00, 45.2MB/s]m
# 100%|██████████| 170M/170M [00:04<00:00, 40.6MB/s]m
#  98%|█████████▊| 168M/170M [00:04<00:00, 47.5MB/s]m
# 100%|██████████| 170M/170M [00:04<00:00, 40.5MB/s]m
# (RayTrainWorker pid=5004, ip=10.0.252.174) Moving model to device: cuda:0
#   0%|          | 0.00/170M [00:00<?, ?B/s].237)
#  90%|████████▉ | 153M/170M [00:03<00:00, 44.7MB/s] [repeated 71x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (RayTrainWorker pid=5004, ip=10.0.252.174) Wrapping provided model in DistributedDataParallel.
# Train Epoch 0:   0%|          | 0/98 [00:00<?, ?it/s]
# Train Epoch 0:   1%|          | 1/98 [00:00<01:03,  1.52it/s]
# (RayTrainWorker pid=4974, ip=10.0.201.237) Moving model to device: cuda:0
# (RayTrainWorker pid=4974, ip=10.0.201.237) Wrapping provided model in DistributedDataParallel.
# Train Epoch 0:   0%|          | 0/98 [00:00<?, ?it/s]
# Train Epoch 0:  16%|█▋        | 16/98 [00:05<00:28,  2.84it/s] [repeated 30x across cluster]
# Train Epoch 0:  32%|███▏      | 31/98 [00:10<00:23,  2.84it/s] [repeated 30x across cluster]
# Train Epoch 0:  47%|████▋     | 46/98 [00:16<00:18,  2.83it/s] [repeated 30x across cluster]
# Train Epoch 0:  62%|██████▏   | 61/98 [00:21<00:13,  2.81it/s] [repeated 30x across cluster]
# Train Epoch 0:  78%|███████▊  | 76/98 [00:26<00:07,  2.81it/s] [repeated 30x across cluster]
# Train Epoch 0:  92%|█████████▏| 90/98 [00:31<00:02,  2.83it/s]
# Train Epoch 0:  91%|█████████ | 89/98 [00:31<00:03,  2.81it/s] [repeated 27x across cluster]
# Train Epoch 0: 100%|██████████| 98/98 [00:34<00:00,  2.83it/s]
# Valid Epoch 0:   0%|          | 0/20 [00:00<?, ?it/s]
# Valid Epoch 0:   5%|▌         | 1/20 [00:00<00:05,  3.64it/s]
# Valid Epoch 0: 100%|██████████| 20/20 [00:02<00:00,  8.82it/s]
# (RayTrainWorker pid=5004, ip=10.0.252.174) metrics={'loss': 1.7364016771316528, 'epoch': 0} world_rank=0
# Train Epoch 0:  99%|█████████▉| 97/98 [00:34<00:00,  2.80it/s] [repeated 15x across cluster]
# (RayTrainWorker pid=5004, ip=10.0.252.174) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_run-006cdd570b2e4a4abe9967513be1b708/checkpoint_2026-03-16_16-24-05.939605)
# (RayTrainWorker pid=5004, ip=10.0.252.174) Reporting training result 1: TrainingReport(checkpoint=Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_run-006cdd570b2e4a4abe9967513be1b708/checkpoint_2026-03-16_16-24-05.939605), metrics={'loss': 1.7364016771316528, 'epoch': 0}, validation=False)
# Train Epoch 1:   0%|          | 0/98 [00:00<?, ?it/s]
# Train Epoch 1:   1%|          | 1/98 [00:00<00:14,  6.48it/s]
# Train Epoch 0: 100%|██████████| 98/98 [00:34<00:00,  2.83it/s]
# Valid Epoch 0:   0%|          | 0/20 [00:00<?, ?it/s]
# Valid Epoch 0:  90%|█████████ | 18/20 [00:02<00:00,  8.99it/s] [repeated 35x across cluster]
# Valid Epoch 0: 100%|██████████| 20/20 [00:02<00:00,  8.64it/s]
# (RayTrainWorker pid=4974, ip=10.0.201.237) metrics={'loss': 1.6248624324798584, 'epoch': 0} world_rank=1
# (RayTrainWorker pid=4974, ip=10.0.201.237) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_run-006cdd570b2e4a4abe9967513be1b708/checkpoint_2026-03-16_16-24-05.939605)
# (RayTrainWorker pid=4974, ip=10.0.201.237) Reporting training result 1: TrainingReport(checkpoint=Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_run-006cdd570b2e4a4abe9967513be1b708/checkpoint_2026-03-16_16-24-05.939605), metrics={'loss': 1.6248624324798584, 'epoch': 0}, validation=False)
# Train Epoch 1:   0%|          | 0/98 [00:00<?, ?it/s]
# Train Epoch 1:  15%|█▌        | 15/98 [00:05<00:29,  2.81it/s] [repeated 28x across cluster]
# Train Epoch 1:  30%|██▉       | 29/98 [00:10<00:24,  2.78it/s] [repeated 28x across cluster]
# Train Epoch 1:  44%|████▍     | 43/98 [00:15<00:19,  2.78it/s] [repeated 28x across cluster]
# Train Epoch 1:  58%|█████▊    | 57/98 [00:20<00:14,  2.78it/s] [repeated 28x across cluster]
# Train Epoch 1:  72%|███████▏  | 71/98 [00:25<00:09,  2.78it/s] [repeated 28x across cluster]
# Train Epoch 1:  87%|████████▋ | 85/98 [00:30<00:04,  2.78it/s] [repeated 28x across cluster]
# Train Epoch 1:  92%|█████████▏| 90/98 [00:32<00:02,  2.78it/s]
# Train Epoch 1: 100%|██████████| 98/98 [00:34<00:00,  2.80it/s]
# Valid Epoch 1:   0%|          | 0/20 [00:00<?, ?it/s]
# Valid Epoch 1:   5%|▌         | 1/20 [00:00<00:05,  3.74it/s]
# Train Epoch 1:  91%|█████████ | 89/98 [00:31<00:03,  2.78it/s] [repeated 9x across cluster]
# Train Epoch 1:  99%|█████████▉| 97/98 [00:34<00:00,  2.78it/s] [repeated 15x across cluster]
# Valid Epoch 1: 100%|██████████| 20/20 [00:02<00:00,  8.77it/s]
# (RayTrainWorker pid=5004, ip=10.0.252.174) metrics={'loss': 1.5367177724838257, 'epoch': 1} world_rank=0
# (RayTrainWorker pid=5004, ip=10.0.252.174) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_run-006cdd570b2e4a4abe9967513be1b708/checkpoint_2026-03-16_16-24-43.647451)
# (RayTrainWorker pid=5004, ip=10.0.252.174) Reporting training result 2: TrainingReport(checkpoint=Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_run-006cdd570b2e4a4abe9967513be1b708/checkpoint_2026-03-16_16-24-43.647451), metrics={'loss': 1.5367177724838257, 'epoch': 1}, validation=False)
# (TrainController pid=14603) [State Transition] RUNNING -> SHUTTING_DOWN.
# Train Epoch 1: 100%|██████████| 98/98 [00:34<00:00,  2.80it/s]
# Valid Epoch 1:   0%|          | 0/20 [00:00<?, ?it/s]
# Valid Epoch 1:  90%|█████████ | 18/20 [00:02<00:00,  8.81it/s] [repeated 35x across cluster]
# Training result: Result(metrics={'loss': 1.5367177724838257, 'epoch': 1}, checkpoint=Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_run-006cdd570b2e4a4abe9967513be1b708/checkpoint_2026-03-16_16-24-43.647451), error=None, path='/mnt/cluster_storage/train_run-006cdd570b2e4a4abe9967513be1b708', metrics_dataframe=       loss  epoch
# 0  1.736402      0
# 1  1.536718      1, best_checkpoints=[(Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_run-006cdd570b2e4a4abe9967513be1b708/checkpoint_2026-03-16_16-24-05.939605), {'loss': 1.7364016771316528, 'epoch': 0}), (Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_run-006cdd570b2e4a4abe9967513be1b708/checkpoint_2026-03-16_16-24-43.647451), {'loss': 1.5367177724838257, 'epoch': 1})], _storage_filesystem=<pyarrow._fs.LocalFileSystem object at 0x7727ccf69630>)
# (TrainController pid=14603) [State Transition] SHUTTING_DOWN -> FINISHED.

# %% [markdown]
# Because you're running training in a data parallel fashion this time, it should take under 1 minute while maintaining similar accuracy.

# %% [markdown]
# Distributed data-parallel training, but now using Ray Train.

# %% [markdown]
# |<img src="https://anyscale-public-materials.s3.us-west-2.amazonaws.com/ray-ai-libraries/diagrams/multi_gpu_pytorch_annotated_v5.png" width="100%" loading="lazy">|
# |:--|
# ||

# %% [markdown]
# ## `Step 3`: Scale data ingest separately from training with Ray Data

# %% [markdown]
# Modify this example to load data with Ray Data instead of the native PyTorch DataLoader. With a few modifications, you can scale data preprocessing and training separately. For example, you can do the former with a pool of CPU workers and the latter with a pool of GPU workers. See [How does Ray Data compare to other solutions for offline inference?](https://docs.ray.io/en/latest/data/comparisons.html#how-does-ray-data-compare-to-other-solutions-for-ml-training-ingest) for a comparison between Ray Data and PyTorch data loading.
#
# First, create [Ray Data Datasets](https://docs.ray.io/en/latest/data/key-concepts.html#datasets-and-blocks) from S3 data and inspect their schemas.

# %% [markdown]
# ### Compare differences on a distributed setup
#
# Let's now look at how PyTorch DataLoader vs Ray Data work in a distributed setup.

# %% [markdown]
# Below is a diagram showing how Pytorch DataLoader works in a distributed setup.
#
# <img src="https://anyscale-materials.s3.us-west-2.amazonaws.com/ray-train-deep-dive/pytorch_dataloader_multi_worker.png" width="800" loading="lazy">

# %% [markdown]
# Below is a diagram showing how Ray Data works in a distributed setup.
#
# <img src="https://anyscale-materials.s3.us-west-2.amazonaws.com/ray-train-deep-dive/ray_data_ray_train_multi_worker.png" width="1000" loading="lazy">

# %% [markdown]
# ### When to Integrate Ray Train with Ray Data
# Use both Ray Train and Ray Data when you face one of the following challenges:
# | Challenge | Detail | Solution |
# | --- | --- | --- |
# | Need a **consistent interface for loading and sharding** data | The training process may need to load data from various sources, such as Parquet, CSV, or lakehouses. | Ray Data provides a standardize approach for loading, shuffling, sharding, and streaming batch data to your distributed training run. |
# | Need to perform online or **just-in-time data processing** on **CPU and GPU nodes** | You are in a scenario where it makes more sense to perform data preprocessing on the fly instead of preprocess your data in batch in a separate job. This usually is the case if preprocessing your data takes an extremely long time (on the order of weeks) and you don't want this to block your training run. | Ray Train's integration with Ray Data makes it easy to implement just-in-time data processing. |

# %% [markdown]
# ### Integration Architecture
#
# Here is a diagram showing the a sample Ray Data and Ray Train integration for a simple homogenous cluster setup
#
# <img src="https://anyscale-materials.s3.us-west-2.amazonaws.com/ray-train-deep-dive/homogeneous_training_ray_train_ray_data.png" width="900" loading="lazy">

# %%
import ray.data

import numpy as np

STORAGE_PATH = "s3://ray-example-data/cifar10-parquet"

train_dataset = ray.data.read_parquet(f'{STORAGE_PATH}/train')
test_dataset = ray.data.read_parquet(f'{STORAGE_PATH}/test')

train_dataset.schema()
test_dataset.schema()
# Out:
# Column  Type
# ------  ----
# image   ArrowTensorType(shape=(32, 32, 3), dtype=uint8)
# label   int64

# %% [markdown]
# Next, use Ray Data to transform the data. Note that both loading and transformation happen lazily, which means that only the training workers materialize the data.

# %%
def transform_cifar(row: Dict[str, np.ndarray]) -> Dict[str, np.ndarray]:
    # Define the torchvision transform.
    transform = transforms.Compose([ToTensor(), Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
    row["image"] = transform(row["image"])
    return row

train_dataset = train_dataset.map(transform_cifar)
test_dataset = test_dataset.map(transform_cifar)

# %% [markdown]
# Next, modify the training function you wrote earlier.

# %%
def train_func_per_worker(config: Dict):
    lr = config["lr"]
    epochs = config["epochs"]
    batch_size = config["batch_size_per_worker"]


    # [1] Prepare `Dataloader` for distributed training.
    # The get_dataset_shard method gets the associated dataset shard to pass to the 
    # TorchTrainer constructor in the next code block.
    # The iter_torch_batches method lazily shards the dataset among workers.
    # =============================================================================
    train_data_shard = ray.train.get_dataset_shard("train")
    valid_data_shard = ray.train.get_dataset_shard("valid")
    train_dataloader = train_data_shard.iter_torch_batches(batch_size=batch_size)
    valid_dataloader = valid_data_shard.iter_torch_batches(batch_size=batch_size)

    model = VisionTransformer(
        image_size=32,   # CIFAR-10 image size is 32x32
        patch_size=4,    # Patch size is 4x4
        num_layers=12,   # Number of transformer layers
        num_heads=8,     # Number of attention heads
        hidden_dim=384,  # Hidden size (can be adjusted)
        mlp_dim=768,     # MLP dimension (can be adjusted)
        num_classes=10   # CIFAR-10 has 10 classes
    )

    model = ray.train.torch.prepare_model(model)

    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-2)

    # Model training loop.
    for epoch in range(epochs):
        model.train()
        for batch in tqdm(train_dataloader, desc=f"Train Epoch {epoch}"):
            X, y = batch['image'], batch['label']
            pred = model(X)
            loss = loss_fn(pred, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        valid_loss, num_correct, num_total, num_batches = 0, 0, 0, 0
        with torch.no_grad():
            for batch in tqdm(valid_dataloader, desc=f"Valid Epoch {epoch}"):
                # [2] Each Ray Data batch is a dict so you must access the
                # underlying data using the appropriate keys.
                # =======================================================
                X, y = batch['image'], batch['label']
                pred = model(X)
                loss = loss_fn(pred, y)

                valid_loss += loss.item()
                num_total += y.shape[0]
                num_batches += 1
                num_correct += (pred.argmax(1) == y).sum().item()

        valid_loss /= num_batches
        accuracy = num_correct / num_total

        metrics = print_metrics_ray_train(loss,  epoch)
        save_checkpoint_and_metrics_ray_train(model, metrics)

# %% [markdown]
# Finally, run the training function with the Ray Data Dataset on the Ray Cluster with 8 GPU workers.

# %%
num_workers=2
use_gpu=True
global_batch_size = 512
lr = 1e-3
epochs = 2

train_config = {
    "lr": lr,
    "epochs": epochs,
    "batch_size_per_worker": global_batch_size // num_workers,
}

scaling_config = ScalingConfig(num_workers=num_workers, 
                               use_gpu=use_gpu)
                               
run_config = RunConfig(storage_path="/mnt/cluster_storage", 
                       name=f"train_data_run-{uuid.uuid4().hex}")

# Initialize a Ray TorchTrainer.
trainer = TorchTrainer(
    train_loop_per_worker=train_func_per_worker,
    # [1] With Ray Data you pass the Dataset directly to the Trainer.
    # ==============================================================
    datasets={"train": train_dataset, "valid": test_dataset},
    train_loop_config=train_config,
    scaling_config=scaling_config,
    run_config=run_config,
)

result = trainer.fit()
print(f"Training result: {result}")
# Out:
# (TrainController pid=17499) [State Transition] INITIALIZING -> SCHEDULING.
# (TrainController pid=17499) Attempting to start training worker group of size 2 with the following resources: [{'GPU': 1}] * 2
# (RayTrainWorker pid=5761, ip=10.0.201.237) Setting up process group for: env:// [rank=0, world_size=2]
# (TrainController pid=17499) Started training worker group of size 2:
# (TrainController pid=17499) - (ip=10.0.201.237, pid=5761) world_rank=0, local_rank=0, node_rank=0
# (TrainController pid=17499) - (ip=10.0.252.174, pid=5645) world_rank=1, local_rank=0, node_rank=1
# (TrainController pid=17499) [State Transition] SCHEDULING -> RUNNING.
# (RayTrainWorker pid=5645, ip=10.0.252.174) Moving model to device: cuda:0
# (RayTrainWorker pid=5645, ip=10.0.252.174) Wrapping provided model in DistributedDataParallel.
# Train Epoch 0: 0it [00:00, ?it/s]=10.0.252.174)
# (raylet) WARNING: 4 PYTHON worker processes have been started on node: 900b5faee8793e5341f8710a9d636a7e245c230f96d0f24639cd5052 with address: 10.0.228.114. This could be a result of using a large number of actors, or due to tasks blocked in ray.get() calls (see https://github.com/ray-project/ray/issues/3644 for some discussion of workarounds).
# (pid=17777) Running Dataset train_4_0.: 0.00 row [00:00, ? row/s]
# (pid=17777) - ListFiles:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=17777) - ReadFiles:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=17777) - Map(transform_cifar):   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=17777) - split(2, equal=True):   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (SplitCoordinator pid=17777) Registered dataset logger for dataset train_4_0
# (SplitCoordinator pid=17777) Starting execution of Dataset train_4_0. Full logs are in /tmp/ray/session_2026-03-16_15-55-45_405237_2377/logs/ray-data
# (SplitCoordinator pid=17777) Execution plan of Dataset train_4_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles] -> TaskPoolMapOperator[Map(transform_cifar)] -> OutputSplitter[split(2, equal=True)]
# (SplitCoordinator pid=17777) ⚠️  Ray's object store is configured to use only 28.0% of available memory (26.9GiB out of 96.0GiB total). For optimal Ray Data performance, we recommend setting the object store to at least 50% of available memory. You can do this by setting the 'object_store_memory' parameter when calling ray.init() or by setting the RAY_DEFAULT_OBJECT_STORE_MEMORY_PROPORTION environment variable.
# (SplitCoordinator pid=17777) [dataset]: A new progress UI is available. To enable, set `ray.data.DataContext.get_current().enable_rich_progress_bars = True` and `ray.data.DataContext.get_current().use_ray_tqdm = False`.
# (RayTrainWorker pid=5761, ip=10.0.201.237) Moving model to device: cuda:0
# (RayTrainWorker pid=5761, ip=10.0.201.237) Wrapping provided model in DistributedDataParallel.
# Train Epoch 0: 0it [00:00, ?it/s]=10.0.201.237)
# (raylet) WARNING: 6 PYTHON worker processes have been started on node: 900b5faee8793e5341f8710a9d636a7e245c230f96d0f24639cd5052 with address: 10.0.228.114. This could be a result of using a large number of actors, or due to tasks blocked in ray.get() calls (see https://github.com/ray-project/ray/issues/3644 for some discussion of workarounds).
# (SplitCoordinator pid=17777) Failed to send resource request for data-train_4_0. If this only happens transiently during network partition or CPU being overloaded, it's safe to ignore this error. If this error persists, file a GitHub issue.
# (SplitCoordinator pid=17777) Traceback (most recent call last):
# (SplitCoordinator pid=17777)   File "/home/ray/anaconda3/lib/python3.13/site-packages/ray/data/_internal/cluster_autoscaler/default_autoscaling_coordinator.py", line 98, in wrapper
# (SplitCoordinator pid=17777)     result = func(self, *args, **kwargs)
# (SplitCoordinator pid=17777)   File "/home/ray/anaconda3/lib/python3.13/site-packages/ray/data/_internal/cluster_autoscaler/default_autoscaling_coordinator.py", line 181, in request_resources
# (SplitCoordinator pid=17777)     ray.get(
# (SplitCoordinator pid=17777)     ~~~~~~~^
# (SplitCoordinator pid=17777)         self._autoscaling_coordinator.request_resources.remote(
# (SplitCoordinator pid=17777)         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (SplitCoordinator pid=17777)     ...<6 lines>...
# (SplitCoordinator pid=17777)         timeout=self.AUTOSCALING_REQUEST_GET_TIMEOUT_S,
# (SplitCoordinator pid=17777)         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (SplitCoordinator pid=17777)     )
# (SplitCoordinator pid=17777)     ^
# (SplitCoordinator pid=17777)   File "/home/ray/anaconda3/lib/python3.13/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
# (SplitCoordinator pid=17777)     return fn(*args, **kwargs)
# (SplitCoordinator pid=17777)   File "/home/ray/anaconda3/lib/python3.13/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
# (SplitCoordinator pid=17777)     return func(*args, **kwargs)
# (SplitCoordinator pid=17777)   File "/home/ray/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 2981, in get
# (SplitCoordinator pid=17777)     values, debugger_breakpoint = worker.get_objects(
# (SplitCoordinator pid=17777)                                   ~~~~~~~~~~~~~~~~~~^
# (SplitCoordinator pid=17777)         object_refs, timeout, use_object_store=_use_object_store
# (SplitCoordinator pid=17777)         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (SplitCoordinator pid=17777)     )
# (SplitCoordinator pid=17777)     ^
# (SplitCoordinator pid=17777)   File "/home/ray/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 982, in get_objects
# (SplitCoordinator pid=17777)     ] = self.core_worker.get_objects(
# (SplitCoordinator pid=17777)         ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
# (SplitCoordinator pid=17777)         object_refs,
# (SplitCoordinator pid=17777)         ^^^^^^^^^^^^
# (SplitCoordinator pid=17777)         timeout_ms,
# (SplitCoordinator pid=17777)         ^^^^^^^^^^^
# (SplitCoordinator pid=17777)     )
# (SplitCoordinator pid=17777)     ^
# (SplitCoordinator pid=17777)   File "python/ray/_raylet.pyx", line 2976, in ray._raylet.CoreWorker.get_objects
# (SplitCoordinator pid=17777)   File "python/ray/includes/common.pxi", line 106, in ray._raylet.check_status
# (SplitCoordinator pid=17777) ray.exceptions.GetTimeoutError: Get timed out: some object(s) not ready.
# (Map(transform_cifar) pid=5750, ip=10.0.252.174) /tmp/ray/session_2026-03-16_15-55-45_405237_2377/runtime_resources/pip/3601966b20521d590458d01765bbd50b115fc6d7/virtualenv/lib/python3.13/site-packages/torchvision/transforms/functional.py:154: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:213.)
# (Map(transform_cifar) pid=5750, ip=10.0.252.174)   img = torch.from_numpy(pic.transpose((2, 0, 1))).contiguous()
# (SplitCoordinator pid=17777) ✔️  Dataset train_4_0 execution finished in 28.42 seconds
# (SplitCoordinator pid=17777) INFO:openlineage.client.client:OpenLineageClient will use `composite` transport
# (Map(transform_cifar) pid=5945, ip=10.0.201.237) /tmp/ray/session_2026-03-16_15-55-45_405237_2377/runtime_resources/pip/3601966b20521d590458d01765bbd50b115fc6d7/virtualenv/lib/python3.13/site-packages/torchvision/transforms/functional.py:154: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:213.)
# (Map(transform_cifar) pid=5945, ip=10.0.201.237)   img = torch.from_numpy(pic.transpose((2, 0, 1))).contiguous()
# (SplitCoordinator pid=17777) INFO:openlineage.client.transport.composite:Stopping OpenLineage CompositeTransport emission after the first successful delivery because `continue_on_success=False`. Transport that emitted the event: <HttpTransport(name=first, kind=http, priority=1)>
# Train Epoch 0: 1it [00:34, 34.78s/it]0.252.174)
# Train Epoch 0: 17it [00:40,  2.49it/s] [repeated 30x across cluster]
# Train Epoch 0: 32it [00:45,  2.81it/s] [repeated 30x across cluster]
# Train Epoch 0: 47it [00:50,  2.82it/s] [repeated 30x across cluster]
# Train Epoch 0: 61it [00:55,  2.82it/s] [repeated 28x across cluster]
# Train Epoch 0: 75it [01:00,  2.79it/s] [repeated 29x across cluster]
# Train Epoch 0: 90it [01:06,  2.78it/s] [repeated 29x across cluster]
# Train Epoch 0: 98it [01:09,  1.42it/s].252.174)
# Valid Epoch 0: 0it [00:00, ?it/s]=10.0.252.174)
# (pid=17823) Running Dataset valid_6_0.: 0.00 row [00:00, ? row/s]
# (pid=17823) - ListFiles:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=17823) - ReadFiles:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=17823) - Map(transform_cifar):   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=17823) - split(2, equal=True):   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (SplitCoordinator pid=17823) Registered dataset logger for dataset valid_6_0
# (SplitCoordinator pid=17823) Starting execution of Dataset valid_6_0. Full logs are in /tmp/ray/session_2026-03-16_15-55-45_405237_2377/logs/ray-data
# (SplitCoordinator pid=17823) Execution plan of Dataset valid_6_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles] -> TaskPoolMapOperator[Map(transform_cifar)] -> OutputSplitter[split(2, equal=True)]
# (SplitCoordinator pid=17823) ⚠️  Ray's object store is configured to use only 28.0% of available memory (26.9GiB out of 96.0GiB total). For optimal Ray Data performance, we recommend setting the object store to at least 50% of available memory. You can do this by setting the 'object_store_memory' parameter when calling ray.init() or by setting the RAY_DEFAULT_OBJECT_STORE_MEMORY_PROPORTION environment variable.
# (SplitCoordinator pid=17823) [dataset]: A new progress UI is available. To enable, set `ray.data.DataContext.get_current().enable_rich_progress_bars = True` and `ray.data.DataContext.get_current().use_ray_tqdm = False`.
# (SplitCoordinator pid=17823) ✔️  Dataset valid_6_0 execution finished in 2.65 seconds
# (SplitCoordinator pid=17823) INFO:openlineage.client.client:OpenLineageClient will use `composite` transport
# Train Epoch 0: 97it [01:08,  2.78it/s] [repeated 15x across cluster]
# (SplitCoordinator pid=17823) INFO:openlineage.client.transport.composite:Stopping OpenLineage CompositeTransport emission after the first successful delivery because `continue_on_success=False`. Transport that emitted the event: <HttpTransport(name=first, kind=http, priority=1)>
# Valid Epoch 0: 1it [00:02,  2.97s/it]0.201.237)
# Valid Epoch 0: 20it [00:04,  4.35it/s].201.237)
# (RayTrainWorker pid=5761, ip=10.0.201.237) metrics={'loss': 1.7085881233215332, 'epoch': 0} world_rank=0
# (pid=17777) Running Dataset train_4_1.: 0.00 row [00:00, ? row/s]
# (pid=17777) - ListFiles:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=17777) - ReadFiles:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=17777) - Map(transform_cifar):   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=17777) - split(2, equal=True):   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# Train Epoch 0: 98it [01:09,  1.42it/s].201.237)
# Valid Epoch 0: 0it [00:00, ?it/s]=10.0.201.237)
# (SplitCoordinator pid=17777) Registered dataset logger for dataset train_4_1
# (SplitCoordinator pid=17777) Starting execution of Dataset train_4_1. Full logs are in /tmp/ray/session_2026-03-16_15-55-45_405237_2377/logs/ray-data
# (SplitCoordinator pid=17777) Execution plan of Dataset train_4_1: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles] -> TaskPoolMapOperator[Map(transform_cifar)] -> OutputSplitter[split(2, equal=True)]
# (RayTrainWorker pid=5761, ip=10.0.201.237) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_data_run-f87d2cc761b642028c349ded7dcc87a1/checkpoint_2026-03-16_16-31-06.394009)
# (RayTrainWorker pid=5761, ip=10.0.201.237) Reporting training result 1: TrainingReport(checkpoint=Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_data_run-f87d2cc761b642028c349ded7dcc87a1/checkpoint_2026-03-16_16-31-06.394009), metrics={'loss': 1.7085881233215332, 'epoch': 0}, validation=False)
# Train Epoch 1: 0it [00:00, ?it/s]=10.0.201.237)
# (Map(transform_cifar) pid=5944, ip=10.0.201.237) /tmp/ray/session_2026-03-16_15-55-45_405237_2377/runtime_resources/pip/3601966b20521d590458d01765bbd50b115fc6d7/virtualenv/lib/python3.13/site-packages/torchvision/transforms/functional.py:154: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:213.)
# (Map(transform_cifar) pid=5944, ip=10.0.201.237)   img = torch.from_numpy(pic.transpose((2, 0, 1))).contiguous()
# Valid Epoch 0: 20it [00:04,  4.27it/s] [repeated 19x across cluster]
# (RayTrainWorker pid=5645, ip=10.0.252.174) metrics={'loss': 1.7930470705032349, 'epoch': 0} world_rank=1
# (RayTrainWorker pid=5645, ip=10.0.252.174) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_data_run-f87d2cc761b642028c349ded7dcc87a1/checkpoint_2026-03-16_16-31-06.394009)
# (RayTrainWorker pid=5645, ip=10.0.252.174) Reporting training result 1: TrainingReport(checkpoint=Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_data_run-f87d2cc761b642028c349ded7dcc87a1/checkpoint_2026-03-16_16-31-06.394009), metrics={'loss': 1.7930470705032349, 'epoch': 0}, validation=False)
# Train Epoch 1: 0it [00:00, ?it/s]=10.0.252.174)
# (SplitCoordinator pid=17777) ✔️  Dataset train_4_1 execution finished in 11.64 seconds
# Train Epoch 1: 1it [00:11, 11.72s/it]0.252.174)
# (SplitCoordinator pid=17777) INFO:openlineage.client.transport.composite:Stopping OpenLineage CompositeTransport emission after the first successful delivery because `continue_on_success=False`. Transport that emitted the event: <HttpTransport(name=first, kind=http, priority=1)>
# Train Epoch 1: 15it [00:16,  2.63it/s] [repeated 29x across cluster]
# Train Epoch 1: 30it [00:22,  2.81it/s] [repeated 29x across cluster]
# Train Epoch 1: 44it [00:27,  2.78it/s] [repeated 28x across cluster]
# Train Epoch 1: 58it [00:32,  2.80it/s] [repeated 29x across cluster]
# Train Epoch 1: 72it [00:37,  2.78it/s] [repeated 28x across cluster]
# Train Epoch 1: 87it [00:42,  2.78it/s] [repeated 29x across cluster]
# Train Epoch 1: 98it [00:46,  2.11it/s].201.237)
# Valid Epoch 1: 0it [00:00, ?it/s]=10.0.201.237)
# (pid=17823) Running Dataset valid_6_1.: 0.00 row [00:00, ? row/s]
# (pid=17823) - ListFiles:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=17823) - ReadFiles:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=17823) - Map(transform_cifar):   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=17823) - split(2, equal=True):   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (SplitCoordinator pid=17823) Registered dataset logger for dataset valid_6_1
# (SplitCoordinator pid=17823) Starting execution of Dataset valid_6_1. Full logs are in /tmp/ray/session_2026-03-16_15-55-45_405237_2377/logs/ray-data
# (SplitCoordinator pid=17823) Execution plan of Dataset valid_6_1: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles] -> TaskPoolMapOperator[Map(transform_cifar)] -> OutputSplitter[split(2, equal=True)]
# (SplitCoordinator pid=17823) ✔️  Dataset valid_6_1 execution finished in 2.18 seconds
# Train Epoch 1: 97it [00:46,  2.78it/s] [repeated 21x across cluster]
# (SplitCoordinator pid=17823) INFO:openlineage.client.transport.composite:Stopping OpenLineage CompositeTransport emission after the first successful delivery because `continue_on_success=False`. Transport that emitted the event: <HttpTransport(name=first, kind=http, priority=1)>
# Valid Epoch 1: 1it [00:02,  2.43s/it]0.201.237)
# Valid Epoch 1: 20it [00:04,  4.88it/s].201.237)
# (RayTrainWorker pid=5761, ip=10.0.201.237) metrics={'loss': 1.4354115724563599, 'epoch': 1} world_rank=0
# (RayTrainWorker pid=5761, ip=10.0.201.237) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_data_run-f87d2cc761b642028c349ded7dcc87a1/checkpoint_2026-03-16_16-31-57.447888)
# (RayTrainWorker pid=5761, ip=10.0.201.237) Reporting training result 2: TrainingReport(checkpoint=Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_data_run-f87d2cc761b642028c349ded7dcc87a1/checkpoint_2026-03-16_16-31-57.447888), metrics={'loss': 1.4354115724563599, 'epoch': 1}, validation=False)
# (TrainController pid=17499) [State Transition] RUNNING -> SHUTTING_DOWN.
# Train Epoch 1: 98it [00:46,  2.11it/s].252.174)
# Valid Epoch 1: 0it [00:00, ?it/s]=10.0.252.174)
# Training result: Result(metrics={'loss': 1.4354115724563599, 'epoch': 1}, checkpoint=Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_data_run-f87d2cc761b642028c349ded7dcc87a1/checkpoint_2026-03-16_16-31-57.447888), error=None, path='/mnt/cluster_storage/train_data_run-f87d2cc761b642028c349ded7dcc87a1', metrics_dataframe=       loss  epoch
# 0  1.708588      0
# 1  1.435412      1, best_checkpoints=[(Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_data_run-f87d2cc761b642028c349ded7dcc87a1/checkpoint_2026-03-16_16-31-06.394009), {'loss': 1.7085881233215332, 'epoch': 0}), (Checkpoint(filesystem=local, path=/mnt/cluster_storage/train_data_run-f87d2cc761b642028c349ded7dcc87a1/checkpoint_2026-03-16_16-31-57.447888), {'loss': 1.4354115724563599, 'epoch': 1})], _storage_filesystem=<pyarrow._fs.LocalFileSystem object at 0x7727ccea11b0>)
# (TrainController pid=17499) [State Transition] SHUTTING_DOWN -> FINISHED.

# %% [markdown]
# Once again your training run should take around 1 minute with similar accuracy. There aren't big performance wins with Ray Data on this example due to the small size of the dataset; for more interesting benchmarking information see [this blog post](https://www.anyscale.com/blog/fast-flexible-scalable-data-loading-for-ml-training-with-ray-data). The main advantage of Ray Data is that it allows you to stream data across heterogeneous compute, maximizing GPU utilization while minimizing RAM usage.

# %% [markdown]
# If you are using an Anyscale Workspace, in addition to the Ray Train and Metrics dashboards you saw in the previous section, you can also view the Ray Data dashboard by clicking **Ray Workloads** and then **Data** where you can view the throughput and status of each [Ray Data operator](https://docs.ray.io/en/latest/data/key-concepts.html#operators-and-plans).
#
# ![Data Dashboard](https://raw.githubusercontent.com/ray-project/ray/master/doc/source/train/examples/pytorch/distributing-pytorch/images/data_dashboard.png)

# %% [markdown]
# #### Note on the checkpoint lifecycle

# %% [markdown]
# Here is the lifecycle of a checkpoint from being created using a local path to being uploaded to persistent storage.
#
# <img src="https://docs.ray.io/en/latest/_images/checkpoint_lifecycle.png" width=800>

# %% [markdown]
# <div class="alert alert-block alert-info">
#   <p><strong>Notes:</strong></p>
#   <ul>
#     <li>
#       Given it is the same model across all workers, we can instead only build the checkpoint on the worker of rank 0.
#       Note that we will still need to call
#       <a href="https://docs.ray.io/en/latest/train/api/doc/ray.train.report.html#ray.train.report" target="_blank">
#         ray.train.report
#       </a> on all workers to ensure that the training loop is synchronized.
#     </li>
#     <li>Ray Train expects all workers to be able to write files to the same persistent storage location.</li>
#     <li>Cloud storage is the recommended persistent storage location.</li>
#   </ul>
# </div>

# %% [markdown]
# ## Ray Train in Production

# %% [markdown]
# Here are some use-cases of using Ray Train in production:
# 1. Canva uses Ray Train + Ray Data to cut down Stable Diffusion training costs by 3.7x. Read this [Anyscale blog post here](https://www.anyscale.com/blog/scalable-and-cost-efficient-stable-diffusion-pre-training-with-ray) and the [Canva  case study here](https://www.anyscale.com/resources/case-study/how-canva-built-a-modern-ai-platform-using-anyscale)
# 2. Anyscale uses Ray Train + Deepspeed to finetune language models. Read more [here](https://github.com/ray-project/ray/tree/master/doc/source/templates/04_finetuning_llms_with_deepspeed).
